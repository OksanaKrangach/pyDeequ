# %%
# %env SPARK_VERSION=3.2.0  # TODO PUT YOUR VALUE
# Out:
# env: SPARK_VERSION=3.2.0  # TODO PUT YOUR VALUE

# %%
# TODO create spark session with jdbc driver path
import pydeequ
from pyspark.sql import SparkSession, Row
from pydeequ.analyzers import *

jdbc_driver_path = "mssql-jdbc-12.6.1.jre11.jar:deequ-2.0.1-spark-3.2.jar"

# Initializing SparkSession
sparkdf = SparkSession.builder \
    .appName("myApp") \
    .config("spark.driver.extraClassPath", jdbc_driver_path) \
    .getOrCreate()

# %%
# TODO connect to DB with Spark using JDBC connection to read the data

db_url = "jdbc:sqlserver://127.0.0.1:1433;databaseName=AdventureWorks2012;encrypt=false"

table_name = "Production.Product"
user = "test" # your user creds here
password  = "test" # your user creds here

db_properties = {
    "user": "test",
    "password": "test",
    "driver": "com.microsoft.sqlserver.jdbc.SQLServerDriver"
}

# Read data from the database table into a DataFrame
df = sparkdf.read.jdbc(url=db_url, table=table_name, properties=db_properties)

df.printSchema()

#spark.sql("SHOW TABLES").show()
# Out:
# root
#  |-- ProductID: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- ProductNumber: string (nullable = true)
#  |-- MakeFlag: boolean (nullable = true)
#  |-- FinishedGoodsFlag: boolean (nullable = true)
#  |-- Color: string (nullable = true)
#  |-- SafetyStockLevel: short (nullable = true)
#  |-- ReorderPoint: short (nullable = true)
#  |-- StandardCost: decimal(19,4) (nullable = true)
#  |-- ListPrice: decimal(19,4) (nullable = true)
#  |-- Size: string (nullable = true)
#  |-- SizeUnitMeasureCode: string (nullable = true)
#  |-- WeightUnitMeasureCode: string (nullable = true)
#  |-- Weight: decimal(8,2) (nullable = true)
#  |-- DaysToManufacture: integer (nullable = true)
#  |-- ProductLine: string (nullable = true)
#  |-- Class: string (nullable = true)
#  |-- Style: string (nullable = true)
#  |-- ProductSubcategoryID: integer (nullable = true)
#  |-- ProductModelID: integer (nullable = true)
#  |-- SellStartDate: timestamp (nullable = true)
#  |-- SellEndDate: timestamp (nullable = true)
#  |-- DiscontinuedDate: timestamp (nullable = true)
#  |-- rowguid: string (nullable = true)
#  |-- ModifiedDate: timestamp (nullable = true)

# %%
### Data Analyzers section

# Analyze data using PyDeequ
analysis_result = AnalysisRunner(sparkdf) \
    .onData(df) \
    .addAnalyzer(Size()) \
    .addAnalyzer(Completeness("ProductID")) \
    .addAnalyzer(Distinctness("ProductID")) \
    .addAnalyzer(Uniqueness(["ProductID", "Name", "ProductNumber"])) \
    .addAnalyzer(Mean("SafetyStockLevel")) \
    .addAnalyzer(Compliance("top SafetyStockLevel", "SafetyStockLevel >= 500")) \
    .addAnalyzer(Sum("ReorderPoint")) \
    .addAnalyzer(Correlation("StandardCost", "ListPrice")) \
    .run()

# Print analysis result
analysis_result_df = AnalyzerContext.successMetricsAsDataFrame(sparkdf, analysis_result)
analysis_result_df.show()
# Out:
# +-----------+--------------------+------------+------------------+
# |     entity|            instance|        name|             value|
# +-----------+--------------------+------------+------------------+
# |     Column|    SafetyStockLevel|        Mean| 535.1507936507936|
# |     Column|           ProductID|Distinctness|               1.0|
# |     Column|top SafetyStockLevel|  Compliance|0.6904761904761905|
# |Mutlicolumn|StandardCost,List...| Correlation|0.9974159499736837|
# |Mutlicolumn|ProductID,Name,Pr...|  Uniqueness|               1.0|
# |    Dataset|                   *|        Size|             504.0|
# |     Column|           ProductID|Completeness|               1.0|
# |     Column|        ReorderPoint|         Sum|          202287.0|
# +-----------+--------------------+------------+------------------+

# %%
### Data profiling section
# TODO profile data here

from pydeequ.profiles import ColumnProfilerRunner

# Run data profiling using PyDeequ
profile_result = ColumnProfilerRunner(sparkdf) \
    .onData(df) \
    .restrictToColumns(['ProductID', 'Name', 'ProductNumber', 'MakeFlag', 'FinishedGoodsFlag', 'StandardCost', 'ListPrice', 'SellStartDate', 'SellEndDate'])\
    .run()

# Print the profiling result
for col, profile in profile_result.profiles.items():
    print(col)
    print(profile)
# Out:
# Name
# StandardProfiles for column: Name: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 511,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 504
#     },
#     "histogram": null
# }
# ListPrice
# NumericProfiles for column: ListPrice: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 104,
#     "dataType": "Fractional",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 438.66624999999937,
#     "maximum": 3578.27,
#     "minimum": 0.0,
#     "sum": 221087.7899999997,
#     "stdDev": 772.8349984287421,
#     "approxPercentiles": []
# }
# SellStartDate
# StandardProfiles for column: SellStartDate: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 4,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# MakeFlag
# StandardProfiles for column: MakeFlag: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "Boolean",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "false",
#             265,
#             0.5257936507936508
#         ],
#         [
#             "true",
#             239,
#             0.4742063492063492
#         ]
#     ]
# }
# ProductNumber
# StandardProfiles for column: ProductNumber: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 481,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {
#         "Boolean": 0,
#         "Fractional": 0,
#         "Integral": 0,
#         "Unknown": 0,
#         "String": 504
#     },
#     "histogram": null
# }
# FinishedGoodsFlag
# StandardProfiles for column: FinishedGoodsFlag: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 2,
#     "dataType": "Boolean",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": [
#         [
#             "true",
#             295,
#             0.5853174603174603
#         ],
#         [
#             "false",
#             209,
#             0.4146825396825397
#         ]
#     ]
# }
# ProductID
# NumericProfiles for column: ProductID: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 510,
#     "dataType": "Integral",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 673.0396825396825,
#     "maximum": 999.0,
#     "minimum": 1.0,
#     "sum": 339212.0,
#     "stdDev": 229.1454761040394,
#     "approxPercentiles": []
# }
# SellEndDate
# StandardProfiles for column: SellEndDate: {
#     "completeness": 0.19444444444444445,
#     "approximateNumDistinctValues": 2,
#     "dataType": "String",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null
# }
# StandardCost
# NumericProfiles for column: StandardCost: {
#     "completeness": 1.0,
#     "approximateNumDistinctValues": 110,
#     "dataType": "Fractional",
#     "isDataTypeInferred": false,
#     "typeCounts": {},
#     "histogram": null,
#     "kll": "None",
#     "mean": 258.60296130952383,
#     "maximum": 2171.2942,
#     "minimum": 0.0,
#     "sum": 130335.89250000002,
#     "stdDev": 461.17461124084446,
#     "approxPercentiles": []
# }

# %%
### Constraint Suggestions section
# TODO find meaninful constraints here

from pydeequ.suggestions import *

suggestion_result = ConstraintSuggestionRunner(sparkdf) \
             .onData(df) \
             .addConstraintRule(DEFAULT()) \
             .run()

# Constraint Suggestions:
for sugg in suggestion_result['constraint_suggestions']:
    print(f"Constraint suggestion for \'{sugg['column_name']}\': {sugg['description']}")
    print(f"The corresponding Python code is: {sugg['code_for_constraint']}\n")
# Out:
# Constraint suggestion for 'ModifiedDate': 'ModifiedDate' is not null
# The corresponding Python code is: .isComplete("ModifiedDate")
#
# Constraint suggestion for 'ReorderPoint': 'ReorderPoint' has value range '375', '750', '75', '3', '600', '45'
# The corresponding Python code is: .isContainedIn("ReorderPoint", ["375", "750", "75", "3", "600", "45"])
#
# Constraint suggestion for 'ReorderPoint': 'ReorderPoint' is not null
# The corresponding Python code is: .isComplete("ReorderPoint")
#
# Constraint suggestion for 'ReorderPoint': 'ReorderPoint' has value range '375', '750', '75', '3' for at least 91.0% of values
# The corresponding Python code is: .isContainedIn("ReorderPoint", ["375", "750", "75", "3"], lambda x: x >= 0.91, "It should be above 0.91!")
#
# Constraint suggestion for 'ReorderPoint': 'ReorderPoint' has no negative values
# The corresponding Python code is: .isNonNegative("ReorderPoint")
#
# Constraint suggestion for 'ProductLine': 'ProductLine' has value range 'R ', 'M ', 'T ', 'S '
# The corresponding Python code is: .isContainedIn("ProductLine", ["R ", "M ", "T ", "S "])
#
# Constraint suggestion for 'ProductLine': 'ProductLine' has value range 'R ', 'M ', 'T ' for at least 90.0% of values
# The corresponding Python code is: .isContainedIn("ProductLine", ["R ", "M ", "T "], lambda x: x >= 0.9, "It should be above 0.9!")
#
# Constraint suggestion for 'ProductLine': 'ProductLine' has less than 50% missing values
# The corresponding Python code is: .hasCompleteness("ProductLine", lambda x: x >= 0.5, "It should be above 0.5!")
#
# Constraint suggestion for 'Name': 'Name' is not null
# The corresponding Python code is: .isComplete("Name")
#
# Constraint suggestion for 'Name': 'Name' is unique
# The corresponding Python code is: .isUnique("Name")
#
# Constraint suggestion for 'rowguid': 'rowguid' is not null
# The corresponding Python code is: .isComplete("rowguid")
#
# Constraint suggestion for 'rowguid': 'rowguid' is unique
# The corresponding Python code is: .isUnique("rowguid")
#
# Constraint suggestion for 'SizeUnitMeasureCode': 'SizeUnitMeasureCode' has value range 'CM '
# The corresponding Python code is: .isContainedIn("SizeUnitMeasureCode", ["CM "])
#
# Constraint suggestion for 'SizeUnitMeasureCode': 'SizeUnitMeasureCode' has less than 70% missing values
# The corresponding Python code is: .hasCompleteness("SizeUnitMeasureCode", lambda x: x >= 0.3, "It should be above 0.3!")
#
# Constraint suggestion for 'SafetyStockLevel': 'SafetyStockLevel' has value range '500', '1000', '100', '4', '800', '60'
# The corresponding Python code is: .isContainedIn("SafetyStockLevel", ["500", "1000", "100", "4", "800", "60"])
#
# Constraint suggestion for 'SafetyStockLevel': 'SafetyStockLevel' is not null
# The corresponding Python code is: .isComplete("SafetyStockLevel")
#
# Constraint suggestion for 'SafetyStockLevel': 'SafetyStockLevel' has value range '500', '1000', '100', '4' for at least 91.0% of values
# The corresponding Python code is: .isContainedIn("SafetyStockLevel", ["500", "1000", "100", "4"], lambda x: x >= 0.91, "It should be above 0.91!")
#
# Constraint suggestion for 'SafetyStockLevel': 'SafetyStockLevel' has no negative values
# The corresponding Python code is: .isNonNegative("SafetyStockLevel")
#
# Constraint suggestion for 'ListPrice': 'ListPrice' is not null
# The corresponding Python code is: .isComplete("ListPrice")
#
# Constraint suggestion for 'ListPrice': 'ListPrice' has no negative values
# The corresponding Python code is: .isNonNegative("ListPrice")
#
# Constraint suggestion for 'Size': 'Size' has value range '44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40', '62', 'S', '54', '50', 'XL', '56', '70'
# The corresponding Python code is: .isContainedIn("Size", ["44", "48", "52", "42", "58", "38", "60", "L", "M", "46", "40", "62", "S", "54", "50", "XL", "56", "70"])
#
# Constraint suggestion for 'Size': 'Size' has value range '44', '48', '52', '42', '58', '38', '60', 'L', 'M', '46', '40' for at least 88.0% of values
# The corresponding Python code is: .isContainedIn("Size", ["44", "48", "52", "42", "58", "38", "60", "L", "M", "46", "40"], lambda x: x >= 0.88, "It should be above 0.88!")
#
# Constraint suggestion for 'Size': 'Size' has less than 63% missing values
# The corresponding Python code is: .hasCompleteness("Size", lambda x: x >= 0.37, "It should be above 0.37!")
#
# Constraint suggestion for 'DaysToManufacture': 'DaysToManufacture' has value range '0', '1', '4', '2'
# The corresponding Python code is: .isContainedIn("DaysToManufacture", ["0", "1", "4", "2"])
#
# Constraint suggestion for 'DaysToManufacture': 'DaysToManufacture' is not null
# The corresponding Python code is: .isComplete("DaysToManufacture")
#
# Constraint suggestion for 'DaysToManufacture': 'DaysToManufacture' has value range '0', '1', '4' for at least 97.0% of values
# The corresponding Python code is: .isContainedIn("DaysToManufacture", ["0", "1", "4"], lambda x: x >= 0.97, "It should be above 0.97!")
#
# Constraint suggestion for 'DaysToManufacture': 'DaysToManufacture' has no negative values
# The corresponding Python code is: .isNonNegative("DaysToManufacture")
#
# Constraint suggestion for 'SellStartDate': 'SellStartDate' is not null
# The corresponding Python code is: .isComplete("SellStartDate")
#
# Constraint suggestion for 'MakeFlag': 'MakeFlag' is not null
# The corresponding Python code is: .isComplete("MakeFlag")
#
# Constraint suggestion for 'ProductSubcategoryID': 'ProductSubcategoryID' has value range '2', '14', '1', '12', '3', '16', '17', '37', '15', '21', '4', '13', '22', '20' for at least 87.0% of values
# The corresponding Python code is: .isContainedIn("ProductSubcategoryID", ["2", "14", "1", "12", "3", "16", "17", "37", "15", "21", "4", "13", "22", "20"], lambda x: x >= 0.87, "It should be above 0.87!")
#
# Constraint suggestion for 'ProductSubcategoryID': 'ProductSubcategoryID' has no negative values
# The corresponding Python code is: .isNonNegative("ProductSubcategoryID")
#
# Constraint suggestion for 'ProductSubcategoryID': 'ProductSubcategoryID' has less than 46% missing values
# The corresponding Python code is: .hasCompleteness("ProductSubcategoryID", lambda x: x >= 0.54, "It should be above 0.54!")
#
# Constraint suggestion for 'Weight': 'Weight' has no negative values
# The corresponding Python code is: .isNonNegative("Weight")
#
# Constraint suggestion for 'Weight': 'Weight' has less than 64% missing values
# The corresponding Python code is: .hasCompleteness("Weight", lambda x: x >= 0.36, "It should be above 0.36!")
#
# Constraint suggestion for 'WeightUnitMeasureCode': 'WeightUnitMeasureCode' has value range 'LB ', 'G  '
# The corresponding Python code is: .isContainedIn("WeightUnitMeasureCode", ["LB ", "G  "])
#
# Constraint suggestion for 'WeightUnitMeasureCode': 'WeightUnitMeasureCode' has value range 'LB ' for at least 92.0% of values
# The corresponding Python code is: .isContainedIn("WeightUnitMeasureCode", ["LB "], lambda x: x >= 0.92, "It should be above 0.92!")
#
# Constraint suggestion for 'WeightUnitMeasureCode': 'WeightUnitMeasureCode' has less than 64% missing values
# The corresponding Python code is: .hasCompleteness("WeightUnitMeasureCode", lambda x: x >= 0.36, "It should be above 0.36!")
#
# Constraint suggestion for 'ProductNumber': 'ProductNumber' is not null
# The corresponding Python code is: .isComplete("ProductNumber")
#
# Constraint suggestion for 'ProductNumber': 'ProductNumber' is unique
# The corresponding Python code is: .isUnique("ProductNumber")
#
# Constraint suggestion for 'FinishedGoodsFlag': 'FinishedGoodsFlag' is not null
# The corresponding Python code is: .isComplete("FinishedGoodsFlag")
#
# Constraint suggestion for 'Class': 'Class' has value range 'L ', 'H ', 'M '
# The corresponding Python code is: .isContainedIn("Class", ["L ", "H ", "M "])
#
# Constraint suggestion for 'Class': 'Class' has value range 'L ', 'H ', 'M ' for at least 99.0% of values
# The corresponding Python code is: .isContainedIn("Class", ["L ", "H ", "M "], lambda x: x >= 0.99, "It should be above 0.99!")
#
# Constraint suggestion for 'Class': 'Class' has less than 56% missing values
# The corresponding Python code is: .hasCompleteness("Class", lambda x: x >= 0.44, "It should be above 0.44!")
#
# Constraint suggestion for 'ProductModelID': 'ProductModelID' has no negative values
# The corresponding Python code is: .isNonNegative("ProductModelID")
#
# Constraint suggestion for 'ProductModelID': 'ProductModelID' has less than 46% missing values
# The corresponding Python code is: .hasCompleteness("ProductModelID", lambda x: x >= 0.54, "It should be above 0.54!")
#
# Constraint suggestion for 'Style': 'Style' has value range 'U ', 'W ', 'M '
# The corresponding Python code is: .isContainedIn("Style", ["U ", "W ", "M "])
#
# Constraint suggestion for 'Style': 'Style' has value range 'U ' for at least 90.0% of values
# The corresponding Python code is: .isContainedIn("Style", ["U "], lambda x: x >= 0.9, "It should be above 0.9!")
#
# Constraint suggestion for 'Style': 'Style' has less than 63% missing values
# The corresponding Python code is: .hasCompleteness("Style", lambda x: x >= 0.37, "It should be above 0.37!")
#
# Constraint suggestion for 'ProductID': 'ProductID' is not null
# The corresponding Python code is: .isComplete("ProductID")
#
# Constraint suggestion for 'ProductID': 'ProductID' has no negative values
# The corresponding Python code is: .isNonNegative("ProductID")
#
# Constraint suggestion for 'ProductID': 'ProductID' is unique
# The corresponding Python code is: .isUnique("ProductID")
#
# Constraint suggestion for 'Color': 'Color' has value range 'Black', 'Silver', 'Red', 'Yellow', 'Blue', 'Multi', 'Silver/Black', 'White', 'Grey'
# The corresponding Python code is: .isContainedIn("Color", ["Black", "Silver", "Red", "Yellow", "Blue", "Multi", "Silver/Black", "White", "Grey"])
#
# Constraint suggestion for 'Color': 'Color' has value range 'Black', 'Silver', 'Red', 'Yellow' for at least 88.0% of values
# The corresponding Python code is: .isContainedIn("Color", ["Black", "Silver", "Red", "Yellow"], lambda x: x >= 0.88, "It should be above 0.88!")
#
# Constraint suggestion for 'Color': 'Color' has less than 54% missing values
# The corresponding Python code is: .hasCompleteness("Color", lambda x: x >= 0.46, "It should be above 0.46!")
#
# Constraint suggestion for 'StandardCost': 'StandardCost' is not null
# The corresponding Python code is: .isComplete("StandardCost")
#
# Constraint suggestion for 'StandardCost': 'StandardCost' has no negative values
# The corresponding Python code is: .isNonNegative("StandardCost")

# %%
### Constraint Verification section
# TODO check selected constraints here and make beautify the report

from pydeequ.checks import *
from pydeequ.verification import *


check = Check(sparkdf, CheckLevel.Warning, "Review Check")


check_result = VerificationSuite(sparkdf) \
    .onData(df) \
    .addCheck(
        check.isUnique("ProductID") \
        .isUnique("Name") \
        .isUnique("ProductNumber") \
        .isComplete("Name") \
        .isComplete("ProductNumber") \
        .isComplete("ListPrice") \
        .isComplete("StandardCost") \
        .isComplete("FinishedGoodsFlag") \
        .isComplete("ModifiedDate") \
        .isComplete("SellStartDate") \
        .isContainedIn("Color", ["Black", "Silver", "Red", "Yellow", "Blue", "Multi", "Silver/Black", "White", "Grey"]) \
        .isContainedIn("Class", ["L ", "H ", "M "]) \
        .isContainedIn("Style", ["U ", "W ", "M "]) \
        .isContainedIn("ProductLine", ["R ", "M ", "T ", "S "]) \
        .isContainedIn("WeightUnitMeasureCode", ["LB ", "G  "]) \
        .hasCompleteness("Size", lambda x: x >= 0.37, "It should be above 0.37!") \
        .isNonNegative("ProductModelID") \
        .isNonNegative("ProductSubcategoryID") \
        .isNonNegative("Weight") \
        .isNonNegative("StandardCost") \
        .isNonNegative("ListPrice")) \
     .run()

print(f"Verification Run Status: {check_result.status}")

check_result_df = VerificationResult.checkResultsAsDataFrame(sparkdf, check_result)
check_result_df.show()
# Out:
# Python Callback server started!
# Verification Run Status: Success
# +------------+-----------+------------+--------------------+-----------------+------------------+
# |       check|check_level|check_status|          constraint|constraint_status|constraint_message|
# +------------+-----------+------------+--------------------+-----------------+------------------+
# |Review Check|    Warning|     Success|UniquenessConstra...|          Success|                  |
# |Review Check|    Warning|     Success|UniquenessConstra...|          Success|                  |
# |Review Check|    Warning|     Success|UniquenessConstra...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|CompletenessConst...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# |Review Check|    Warning|     Success|ComplianceConstra...|          Success|                  |
# +------------+-----------+------------+--------------------+-----------------+------------------+
# only showing top 20 rows

# %%
# Save Constraint Verification results in the check_results.csv file

check_result_df.coalesce(1).write.mode('overwrite').option("header", "true").csv('check_results.csv')

# %%
# Save Constraint Verification results in the check_results.html file

import pandas as pd
import webbrowser
import os

# Convert the Spark DataFrame back to a Pandas DataFrame using Arrow
result_pdf = check_result_df.select("*").toPandas()

# Convert the Pandas DataFrame to HTML
result_html = result_pdf.to_html()

#Write HTML String to file.html
with open('check_results.html', 'w') as f:
    f.write(result_html)

# Open the result_file.html in the browser
webbrowser.open('file://' + os.path.realpath('check_results.html'))


# Stop SparkSession
sparkdf.sparkContext._gateway.shutdown_callback_server()
sparkdf.stop()
